# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("AmesHousing.csv")
df.sample(5)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2636   2637  902100130           70        RM          57.0      9906   Pave
# 2050   2051  905101070           20        RL          62.0     14299   Pave
# 34       35  527453150          120        RL          24.0      2280   Pave
# 221     222  905105070           20        RL           NaN      8246   Pave
# 1023   1024  527325240           20        RL          90.0     13068   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 2636  Grvl       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2050   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 34     NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 221    NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# 1023   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
#
# ...

# %%
sns.scatterplot(data=df,x="Lot Area",y="SalePrice",hue="MS Zoning",style="Street",size="Land Contour")
# Out:
# <Axes: xlabel='Lot Area', ylabel='SalePrice'>

# %%
sns.countplot(x=df["MS Zoning"])
plt.show()

sns.countplot(x=df["Street"])
plt.show()

sns.countplot(x=df["Sale Type"])
plt.show()

sns.countplot(x=df["Street"])
plt.show()

sns.histplot(df["Pool Area"])
plt.show()

# %%
print(df["SalePrice"].mean())

sns.boxplot(y=df["SalePrice"])
plt.show()

sns.boxplot(y=df["Lot Frontage"])
plt.show()
# Out:
# 180796.0600682594

# %%
df_new=df.select_dtypes(include="number")
df_new.corr()
# Out:
#                     Order       PID  MS SubClass  Lot Frontage  Lot Area  \
# Order            1.000000  0.173593     0.011797     -0.007034  0.031354
# PID              0.173593  1.000000    -0.001281     -0.096918  0.034868
# MS SubClass      0.011797 -0.001281     1.000000     -0.420135 -0.204613
# Lot Frontage    -0.007034 -0.096918    -0.420135      1.000000  0.491313
# Lot Area         0.031354  0.034868    -0.204613      0.491313  1.000000
# Overall Qual    -0.048500 -0.263147     0.039419      0.212042  0.097188
# Overall Cond    -0.011054  0.104451    -0.067349     -0.074448 -0.034759
# Year Built      -0.052319 -0.343388     0.036579      0.121562  0.023258
# Year Remod/Add  -0.075566 -0.157111     0.043397      0.091712  0.021682
# Mas Vnr Area    -0.030907 -0.229283     0.002730      0.222407  0.126830
# BsmtFin SF 1    -0.032321 -0.098375    -0.060075      0.215583  0.191555
# BsmtFin SF 2    -0.002773 -0.001145    -0.070946      0.045999  0.083150
# ...
