# %% [markdown]
# A voting ensemble is an ensemble machine learning technique used primarily for classification tasks. It combines the predictions from multiple different models to produce a single prediction — the idea being that a group decision (ensemble) is more accurate than any individual model.

# %% [markdown]
# # assumptions for applying it
#
# -models are not very same
#
# -models are at least 51% accurate
#
#     else it will even decrease the final accuracy
