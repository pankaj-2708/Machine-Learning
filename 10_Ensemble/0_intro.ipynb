# %% [markdown]
# In machine learning, an ensemble refers to a group of multiple models working together to make a prediction or classification, rather than relying on a single model. The goal is to combine the strengths of these individual models to improve overall performance, reduce errors, and create a more robust and accurate AI model
#
#
# <img src="../images/esemble.png">
# <img src="../images/esemble (2).png">
