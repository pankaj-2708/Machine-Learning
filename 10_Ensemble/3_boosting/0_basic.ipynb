# %% [markdown]
# ## Boosting is an ensemble technique that builds a strong learner by combining multiple weak learners trained sequentially, where each new model focuses on fixing the errors made by the previous ones.

# %% [markdown]
# # Boosting vs Bagging
#
# <a href="https://www.geeksforgeeks.org/machine-learning/bagging-vs-boosting-in-machine-learning/" > read here </a>
