# %%
# it wont work beacuse there is no data

from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeClassifier

bg=BaggingRegressor(
    estimator=DecisionTreeClassifier(),
    n_estimators=10,
    max_samples=0.8, #
    max_features=0.8, #control random subspaces
    bootstrap=True,   # control Pasting
    oob_score=True,
    random_state=42
)


scores = cross_val_score(bg, X_full, y_full, cv=10)

print("Mean Cross-validated accuracy:", scores.mean())
print("Best Cross-validated accuracy:", scores.max())
