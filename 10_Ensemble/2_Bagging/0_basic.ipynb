# %% [markdown]
# <img src="../../images/bagging.png"/>
# <img src="../../images/bagging2.png"/>

# %% [markdown]
# ## random forest - bagging for descision tree
#
# ## generally in bagging we give same type of model eg only descision trees,only lg etc

# %% [markdown]
# # variations of bagging
#
# 1- random subspaces
#
#     in this we train diff models with diff no of columns
#
# 2- Pasting
#
#     Like bagging, but samples without replacement.
#
#  5. Random Patches
#
#     Combines row sampling and feature sampling
#
#     Useful for extremely large datasets

# %% [markdown]
# # oob score
#
# when we do bagging it happens that approximately 37 % of our rows/features are never used so we can use them as testing and their score is known as oob score can be seen by given value of param oob score as true
