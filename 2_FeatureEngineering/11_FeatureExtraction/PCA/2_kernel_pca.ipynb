# %% [markdown]
# prerequistes - kernel concept of SVM

# %% [markdown]
# In kernel pca we just use Kernel matrix instead of covariance matrix .<br>
# By doing so we ensure that we map out data to higher dimesion and then reduce it's dimensinllaty
#
# <img src='../../../images/k_pca.png'>

# %%
from sklearn.decomposition import KernelPCA
rbf_pca = KernelPCA(n_components = 2, kernel="rbf", gamma=0.04)
X_reduced = rbf_pca.fit_transform(X)
