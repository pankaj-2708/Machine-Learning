# %%
in xg boost tree used are different from that are in sckit-learn or used in gradient boosting 

in this the split is done by gain in similarity score instead of gain in gini/entropy it is calulated as 

and also the leaf node's value is calculated by
