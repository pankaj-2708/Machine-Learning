# %% [markdown]
# <img src='../images/xGboost (6).png'>
# <img src='../images/xGboost (7).png'>
# <img src='../images/xGboost (8).png'>
# <img src='../images/xGboost (9).png'>
# <img src='../images/xGboost (10).png'>
# <img src='../images/xGboost (11).png'>

# %% [markdown]
# # mathematics
#
# the main difference between xg boost and gradient boosting come from the way trees are created in them
#
# in xg boost we use similarity score instead of gini / entropy
#
# <img src='../images/xgM.png'>

# %% [markdown]
# ## like in gradient we choose any differntiable loss function here we extend that idea and add some penalties to loss fn and we call this new function as objective function
#
# <img src='../images/pnealty.png'>
#
# Here l is a differentiable convex loss function that measures
# the difference between the prediction ˆyi and the target yi.
# The second term Ω penalizes the complexity of the model
# (i.e., the regression tree functions)
#
# here T is the no of leaf nodes in a model and w is the output of each leaf node and lambda and gamma are regularization terms

# %% [markdown]
# <a src='https://medium.com/@pankajmaulekhi32/demystifying-xgboost-the-math-behind-the-magic-240c25dd8b6a'>Derivation read at medium</a>

# %% [markdown]
# # Derivation
#
# <img src='../images/der (1).jpg'>
# <img src='../images/der (2).jpg'>
# <img src='../images/der (3).jpg'>
# <img src='../images/der (4).jpg'>
# <img src='../images/der (5).jpg'>
# <img src='../images/der (6).jpg'>
# <img src='../images/der (7).jpg'>
# <img src='../images/der (8).jpg'>
# <img src='../images/der (9).jpg'>
