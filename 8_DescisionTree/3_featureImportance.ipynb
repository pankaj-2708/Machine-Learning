# %% [markdown]
# # we can calulate importance of every feature in descision tree
#
# <img src="../images/featureImp (1).png">
# <img src="../images/featureImp (2).png">

# %% [raw]
# it can be seen using attribute feature_importance in descision tree
#
# it is same for both desciion tree regressor and classifier
