# %%
# in multiple linear reg there is multiple x and 1 y

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.datasets import make_regression
import numpy as np
import seaborn as sns

# %%
# by make regression we can clculate data for regression

X,y=make_regression(n_samples=1000,n_features=2,n_targets=1,n_informative=2,noise=50)

df=pd.DataFrame({"feature1":X[:,0],"feature2":X[:,1],"output":y})
df.sample(5)
# Out:
#      feature1  feature2      output
# 829 -1.206968  1.664964   54.423956
# 795  0.395437 -1.649533 -116.396175
# 586 -0.969736  0.361035   17.922245
# 38  -0.868293 -1.151806 -128.753580
# 121  1.128540  0.465371   37.197312

# %%
px.scatter_3d(x=df["feature1"],y=df["feature2"],z=df["output"])

# %%
from sklearn.model_selection import train_test_split

X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()

lr.fit(X_train,y_train)

y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("MSE:", mse)
print("MAE:", mae)
print("r2score:", r2)
# adjusted r2 score
adjusted_r2_score=1-(1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-1-1)
print("adjusted_r2_score",adjusted_r2_score)
# Out:
# MSE: 1843.306592110385
# MAE: 34.0979983162418
# r2score: 0.8630482562737002
# adjusted_r2_score 0.8624960315006103

# %%
slopes=lr.coef_
intercept=lr.intercept_
slopes,intercept
# Out:
# (array([63.90730513, 72.26850213]), np.float64(-2.3288126463362406))
