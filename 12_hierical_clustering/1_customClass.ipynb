# %%
class Agg_Hierical_clust:
    def __init__(self,n_clusters):
        self.n=n_clusters
        self.clusters=None

    
    def train(self,X):
        self.clusters=[[i] for i in range(len(X))]
        while len(self.clusters)>self.n:
            min_dist=float('inf')
            min_i=None
            min_j=None
            for i in range(len(clusters)):
                for j in range(i+1,len(clusters)):
                    
                    dist=min( cal_dist[X[p],X[q]] for p in self.cluster[i] for q in self.cluster[j] )
                    
                    if dist<min_dist:
                        dist=min_dist
                        min_i,min_j=i,j
                        
            self.clusters.pop(min_i)
            self.clusters.pop(min_j)

            self.clusters.append(self.clusters[min_i]+self.clusters[min_j])
            

    def predict(self,X):
        ans=[]
        for pt in X:
            dist=float("inf")
            cluster_no=-1
            for k in range(len(self.clusters)):
                dist=min(cal_dist(pt,i ) for i  in self.clusters[k])
                if dist<min_dist:
                    cluster_no=k
                    dist=min_dist
            ans.append(cluster_no)
        return ans

def cal_dist(a,b):
    return np.linalg.norm(a - b)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs
import scipy.cluster.hierarchy as sc
import plotly.express as px

# %%
X,y=make_blobs(n_samples=200,n_features=2,centers=4)

# %%
px.scatter(x=X[:,0],y=X[:,1],color=y)

# %%
import scipy.cluster.hierarchy as sc

x=sc.dendrogram(sc.linkage(X,method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

ag=AgglomerativeClustering(n_clusters=3,metric='euclidean',linkage='ward')

ag.fit(X)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
px.scatter(x=X[:,0],y=X[:,1],color=list(ag.labels_))

# %%
ag.labels_
# Out:
# array([1, 0, 1, 2, 2, 1, 2, 0, 2, 1, 1, 2, 0, 1, 2, 0, 0, 0, 1, 1, 1, 2,
#        1, 1, 1, 0, 0, 1, 1, 0, 0, 0, 2, 2, 1, 2, 1, 2, 0, 2, 2, 1, 0, 0,
#        0, 1, 1, 0, 2, 2, 0, 0, 0, 0, 0, 0, 0, 0, 2, 1, 0, 0, 2, 2, 0, 1,
#        1, 0, 1, 2, 1, 0, 0, 2, 2, 0, 1, 0, 0, 2, 2, 0, 1, 1, 0, 2, 1, 0,
#        1, 2, 1, 0, 1, 0, 0, 2, 1, 2, 2, 1], dtype=int64)

# %%
np.array([[1,2,3],[4,5,6]]).min()
# Out:
# 1
